# %%
import time
from pymycobot.mycobot280 import MyCobot280 # main robot class
from pymycobot.mypalletizer import MyPalletizer
from pymycobot.mybuddy import MyBuddy 
from pymycobot import MyCobotSocket # socket connection class

# %% [markdown]
# Conexión por puerto

# %%
mc = MyCobot280("COM7", 115200)

# %% [markdown]
# Conexión por WIFI

# %%
# Envio de credenciales WiFi
mc.set_ssid_pwd("IA_Lab_AP", "ia_lab_ap_2025")

# %%
mc = MyCobotSocket("192.168.1.64", 9000)

# %% [markdown]
# Pruebas

# %%
mc.release_all_servos()

# %%
mc.send_angles([0, 0, 0, 0, 0, 0], 50)
# Out:
# -1

# %%
# %pip install inputs
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from inputs import devices

# %%
devices.gamepads
# Out:
# []
